# %% [markdown]
# ## Outline Of The Project

# %% [markdown]
# In this project, I will try to apply CRISP-DM rules and will try to come up with 3 questions for the business and then answer these question with data.
#
# I will work on both `Seattle AirBnb` and `Boston Airbnb` datasets to see their similarities and their differences.

# %%
# Import main libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# I will try to dig deep into the datasets for both `Seattle` and `Boston`. And after I understand the business details, I will come up with three different questions to look on.

# %% [markdown]
# ### 1.1. Seattle Data

# %%
seattle_listings = pd.read_csv('data/seattle/listings.csv')
seattle_listings.head(3)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2318  https://www.airbnb.com/rooms/2318  20200521035945   2020-05-21
# 1  6606  https://www.airbnb.com/rooms/6606  20200521035945   2020-05-21
# 2  9419  https://www.airbnb.com/rooms/9419  20200521035945   2020-05-21
#
#                                                 name  \
# 0  Casa Madrona - Urban Oasis 1 block from the park!
# 1                Fab, private seattle urban cottage!
# 2                Glorious sun room w/ memory foambed
#
#                                              summary  \
# 0  Gorgeous, architect remodeled, Dutch Colonial ...
# 1  This tiny cottage is only 15x10, but it has ev...
# 2  This beautiful double room features a magical ...
#
#                                                space  \
# 0  This beautiful, gracious home has been complet...
# 1  Soo centrally located, this is a little house ...
# 2  Our new Sunny space has a private room from th...
#
#                                          description experiences_offered  \
# 0  Gorgeous, architect remodeled, Dutch Colonial ...                none
# 1  This tiny cottage is only 15x10, but it has ev...                none
# 2  This beautiful double room features a magical ...                none
#
#                                neighborhood_overview  \
# 0  Madrona is a hidden gem of a neighborhood. It ...
# 1  A peaceful yet highly accessible neighborhood,...
# 2  Lots of restaurants (see our guide book) bars,...
#
#                                                notes  \
# 0  We adhere to a 10pm -9am quiet hour schedule, ...
# 1  Check in is at three, if you'd like a snack or...
# 2  This area is an arts district,you will see all...
#
#                                              transit  \
# 0                                                NaN
# 1                                                NaN
# 2  Car 2 go is in this neigborhood Bus is across ...
#
#                                               access  \
# 0           Guests can access any part of the house.
# 1                                                NaN
# 2  24 /7 access kitchen, bathroom and community s...
#
#                                          interaction  \
# 0  We are a family who live next door and are ava...
# 1  I often escape to kingston and my place on the...
# 2  I have a hands on warm approach to guests but ...
#
#                                          house_rules  thumbnail_url  \
# 0                                                NaN            NaN
# 1  Please treat the cottage as if it were your ow...            NaN
# 2  No drugs,no smoking inside *outside in front o...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/02973ad3-a...
# 1         NaN  https://a0.muscache.com/im/pictures/45742/2111...
# 2         NaN  https://a0.muscache.com/im/pictures/56645186/e...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN     2536   https://www.airbnb.com/users/show/2536
# 1             NaN    14942  https://www.airbnb.com/users/show/14942
# 2             NaN    30559  https://www.airbnb.com/users/show/30559
#
#    host_name  host_since                       host_location  \
# 0      Megan  2008-08-26  Seattle, Washington, United States
# 1      Joyce  2009-04-26  Seattle, Washington, United States
# 2  Angielena  2009-08-09  Seattle, Washington, United States
#
#                                           host_about  host_response_time  \
# 0  I welcome guests from all walks of life and ev...  within a few hours
# 1  I am a therapist/innkeeper.I know my city well...      within an hour
# 2  I am a visual artist who is  the  director of ...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                67%                  88%                 t
# 1               100%                  92%                 f
# 2                90%                  91%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/016a1...
# 1  https://a0.muscache.com/im/users/14942/profile...
# 2  https://a0.muscache.com/im/users/30559/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/016a1...              Minor
# 1  https://a0.muscache.com/im/users/14942/profile...        Wallingford
# 2  https://a0.muscache.com/im/users/30559/profile...         Georgetown
#
#    host_listings_count  host_total_listings_count  \
# 0                    2                          2
# 1                    5                          5
# 2                    8                          8
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                      street neighbourhood  \
# 0                      f  Seattle, WA, United States       Madrona
# 1                      t  Seattle, WA, United States   Wallingford
# 2                      t  Seattle, WA, United States    Georgetown
#
#   neighbourhood_cleansed neighbourhood_group_cleansed     city state zipcode  \
# 0                Madrona                 Central Area  Seattle    WA   98122
# 1            Wallingford          Other neighborhoods  Seattle    WA   98103
# 2             Georgetown          Other neighborhoods  Seattle    WA   98108
#
#     market smart_location country_code        country  latitude  longitude  \
# 0  Seattle    Seattle, WA           US  United States  47.61082 -122.29082
# 1  Seattle    Seattle, WA           US  United States  47.65411 -122.33761
# 2  Seattle    Seattle, WA           US  United States  47.55017 -122.31937
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t         House  Entire home/apt             9        2.5
# 1                 t    Guesthouse  Entire home/apt             2        1.0
# 2                 t     Apartment     Private room             2        3.0
#
#    bedrooms  beds  bed_type  \
# 0       4.0   4.0  Real Bed
# 1       1.0   1.0  Real Bed
# 2       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {Internet,Wifi,Kitchen,"Free parking on premis...          NaN  $296.00
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $90.00
# 2  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...        200.0   $62.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $500.00      $250.00                8
# 1      $670.00           NaN          $200.00       $40.00                2
# 2      $580.00     $1,500.00          $100.00       $20.00                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $25.00               1            1125                       1
# 1       $10.00              30            1125                      30
# 2       $15.00               2             180                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       1                    1125                    1125
# 1                      30                    1125                    1125
# 2                       2                     180                     180
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     1.0                  1125.0            today
# 1                    30.0                  1125.0     6 months ago
# 2                     2.0                   180.0     3 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               29               59               89
# 1                t               29               59               89
# 2                t               29               59               89
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               132            2020-05-21                 32
# 1                89            2020-05-21                150
# 2               364            2020-05-21                148
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      7   2008-09-15  2020-02-01                 100.0
# 1                     14   2009-07-17  2019-09-28                  92.0
# 2                     14   2010-07-30  2019-12-27                  93.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                     9.0                        9.0                   10.0
# 2                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                  9.0
# 2                         10.0                    10.0                 10.0
#
#   requires_license             license             jurisdiction_names  \
# 0                t  STR-OPLI-19-002837  {WASHINGTON," Seattle"," WA"}
# 1                t                 NaN  {WASHINGTON," Seattle"," WA"}
# 2                t  str-opli-19-003039  {WASHINGTON," Seattle"," WA"}
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                t                        f  strict_14_with_grace_period
# 1                f                        f  strict_14_with_grace_period
# 2                f                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             t                                t
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               3
# 2                               7
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            3
# 2                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             7
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.22
# 1                                            0               1.14
# 2                                            0               1.24

# %%
seattle_listings.shape
# Out:
# (7017, 106)

# %%
seattle_calendar = pd.read_csv('data/seattle/calendar.csv')
seattle_calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        2318  2020-05-21         f  $243.00        $243.00               1
# 1      708774  2020-05-21         f  $105.00        $105.00              30
# 2      708774  2020-05-22         f  $120.00        $120.00              30
# 3      708774  2020-05-23         f  $120.00        $120.00              30
# 4      708774  2020-05-24         f  $105.00        $105.00              30
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
seattle_max_calendar_d = seattle_calendar.date.max()
seattle_min_calendar_d = seattle_calendar.date.min()

print("The dates between {} and {} have been shown for availability for listings!".format(seattle_min_calendar_d, 
                                                                                         seattle_max_calendar_d))
# Out:
# The dates between 2020-05-21 and 2021-05-24 have been shown for availability for listings!

# %%
seattle_reviews = pd.read_csv('data/seattle/reviews.csv')
seattle_reviews.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0        2318        146  2008-09-15         2451         Kevin
# 1        2318  126302712  2017-01-10     12332845       Jessica
# 2        2318  140977084  2017-04-01      4789466          Ivan
# 3        2318  147262504  2017-04-25     55817131          Mike
# 4        2318  161806368  2017-06-18    113604590          Pete
#
#                                             comments
# 0        1000 times better than staying at a hotel.
# 1  Our family (two couples, a two year old and an...
# 2  Top of the list locations we have stayed at! T...
# 3  SUCH an awesome place. Very clean, quiet and s...
# 4  We flew quite a distance to be at our only dau...

# %% [markdown]
# ### 1.2. Boston Data

# %%
boston_listings = pd.read_csv('data/boston/listings.csv')
boston_listings.head(3)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20200610033559   2020-06-10
# 1  5506  https://www.airbnb.com/rooms/5506  20200610033559   2020-06-10
# 2  6695  https://www.airbnb.com/rooms/6695  20200610033559   2020-06-10
#
#                                              name  \
# 0                       HARBORSIDE-Walk to subway
# 1  **$49 Special **   Private! Minutes to center!
# 2                  $99 Special!! Home Away! Condo
#
#                                              summary  \
# 0  Fully separate apartment in a two apartment bu...
# 1  Private guest room with private bath, You do n...
# 2  Comfortable,  Fully Equipped private apartment...
#
#                                                space  \
# 0  This is a totally separate apartment located o...
# 1  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# 2  ** WELCOME *** FULL PRIVATE APARTMENT In a His...
#
#                                          description experiences_offered  \
# 0  Fully separate apartment in a two apartment bu...                none
# 1  Private guest room with private bath, You do n...                none
# 2  Comfortable,  Fully Equipped private apartment...                none
#
#                                neighborhood_overview  \
# 0  Mostly quiet ( no loud music, no crowed sidewa...
# 1  Peacful, Architecturally interesting, historic...
# 2  Peaceful, Architecturally interesting, histori...
#
#                                                notes  \
# 0  Building is on quiet side of airport. Building...
# 1  Guest room is on the 3rd floor,  Steps are req...
# 2  Check out some of the other accommodations we ...
#
#                                              transit  \
# 0  Local subway stop ( Maverick Station on the Bl...
# 1  Excellent Access to all of Boston, Walk to Mus...
# 2  We are a 5 minute walk to the subway,  5 minut...
#
#                                               access  \
# 0  Guests solely occupy the 1 floor apartment wit...
# 1  You get full access to the guest room with pri...
# 2  Full Private apartment.  1 bedroom,  kitchen, ...
#
#                                          interaction  \
# 0  We sometimes travel. Always available via: mob...
# 1  We give guests privacy,  but we are available ...
# 2                                                NaN
#
#                    house_rules  thumbnail_url  medium_url  \
# 0         No pets, no smoking.            NaN         NaN
# 1  No Smoking in the Building.            NaN         NaN
# 2  No Smoking in the Building.            NaN         NaN
#
#                                          picture_url  xl_picture_url  host_id  \
# 0  https://a0.muscache.com/im/pictures/24670/b2de...             NaN     4804
# 1  https://a0.muscache.com/im/pictures/1598e8b6-5...             NaN     8229
# 2  https://a0.muscache.com/im/pictures/38ac4797-e...             NaN     8229
#
#                                  host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/4804     Frank  2008-12-03
# 1  https://www.airbnb.com/users/show/8229     Terry  2009-02-19
# 2  https://www.airbnb.com/users/show/8229     Terry  2009-02-19
#
#                           host_location  \
# 0                         Massachusetts
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
#
#                                           host_about host_response_time  \
# 0  My wife and I and grown children frequently oc...       within a day
# 1              Relaxed,  Easy going, Accommodating.      within an hour
# 2              Relaxed,  Easy going, Accommodating.      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                75%                  44%                 t
# 1               100%                 100%                 t
# 2               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/4804/profile_...
# 1  https://a0.muscache.com/im/users/8229/profile_...
# 2  https://a0.muscache.com/im/users/8229/profile_...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/4804/profile_...        East Boston
# 1  https://a0.muscache.com/im/users/8229/profile_...            Roxbury
# 2  https://a0.muscache.com/im/users/8229/profile_...            Roxbury
#
#    host_listings_count  host_total_listings_count  \
# 0                  5.0                        5.0
# 1                  2.0                        2.0
# 2                  2.0                        2.0
#
#                      host_verifications host_has_profile_pic  \
# 0         ['email', 'phone', 'reviews']                    t
# 1  ['email', 'phone', 'reviews', 'kba']                    t
# 2  ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                     street neighbourhood  \
# 0                      f  Boston, MA, United States   East Boston
# 1                      t  Boston, MA, United States       Roxbury
# 2                      t  Boston, MA, United States       Roxbury
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed    city state zipcode  \
# 0            East Boston                           NaN  Boston    MA   02128
# 1                Roxbury                           NaN  Boston    MA   02119
# 2                Roxbury                           NaN  Boston    MA   02119
#
#    market smart_location country_code        country  latitude  longitude  \
# 0  Boston     Boston, MA           US  United States  42.36413  -71.02991
# 1  Boston     Boston, MA           US  United States  42.32981  -71.09559
# 2  Boston     Boston, MA           US  United States  42.32994  -71.09351
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t     Apartment  Entire home/apt             2        1.0
# 1                 t   Guest suite  Entire home/apt             2        1.0
# 2                 t   Condominium  Entire home/apt             4        1.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   0.0  Real Bed
# 1       1.0   1.0  Real Bed
# 2       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN  $125.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        225.0  $145.00
# 2  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $169.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $750.00     $2,250.00            $0.00       $75.00                2
# 1      $980.00     $3,000.00            $0.00       $60.00                1
# 2          NaN           NaN            $0.00       $80.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0        $0.00              28            1125                      28
# 1        $0.00               3             730                       3
# 2        $8.00               3             730                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                      28                    1125                    1125
# 1                       3                    1125                    1125
# 2                       3                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                    28.0                  1125.0     4 months ago
# 1                     3.0                  1125.0     3 months ago
# 2                     3.0                   730.0     3 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                7
# 1                t               10               40               70
# 2                t               10               33               56
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                97            2020-06-10                 16
# 1               333            2020-06-10                107
# 2               317            2020-06-10                115
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      1   2015-07-10  2019-12-21                  99.0
# 1                     17   2009-03-21  2020-05-01                  95.0
# 2                     19   2009-08-06  2019-11-02                  96.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                     9.0                 10.0
# 2                         10.0                     9.0                 10.0
#
#   requires_license                                            license  \
# 0                t                                                NaN
# 1                t  Exempt: This listing is a unit that has contra...
# 2                t                                         STR-404620
#
#                                jurisdiction_names instant_bookable  \
# 0  {"Massachusetts State"," Massachusetts State"}                f
# 1  {"Massachusetts State"," Massachusetts State"}                t
# 2  {"Massachusetts State"," Massachusetts State"}                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f              super_strict_30
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               6
# 2                               6
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            6
# 2                                            6
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.27
# 1                                            0               0.78
# 2                                            0               0.87

# %%
boston_listings.shape
# Out:
# (3440, 106)

# %%
boston_calendar = pd.read_csv('data/boston/calendar.csv')
boston_calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        3781  2020-06-10         f  $125.00        $125.00              28
# 1        3781  2020-06-11         f  $125.00        $125.00              28
# 2        3781  2020-06-12         f  $125.00        $125.00              28
# 3        3781  2020-06-13         f  $125.00        $125.00              28
# 4        3781  2020-06-14         f  $125.00        $125.00              28
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
boston_max_calendar_d = seattle_calendar.date.max()
boston_min_calendar_d = seattle_calendar.date.min()

print("The dates between {} and {} have been shown for availability for listings!".format(boston_min_calendar_d, 
                                                                                         boston_max_calendar_d))
# Out:
# The dates between 2020-05-21 and 2021-05-24 have been shown for availability for listings!

# %%
boston_reviews = pd.read_csv('data/boston/reviews.csv')
boston_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        3781  37776825  2015-07-10     36059247          Greg
# 1        3781  41842494  2015-08-09     10459388           Tai
# 2        3781  45282151  2015-09-01     12264652        Damien
# 3        3781  49022647  2015-09-30     41426327          Mike
# 4        3781  52503327  2015-10-30     15151513          Ivan
#
#                                             comments
# 0  The apartment was as advertised and Frank was ...
# 1  It was a pleasure to stay at Frank's place. Th...
# 2  The apartment description is entirely faithful...
# 3  Thoroughly enjoyed my time at Frank's home. Ha...
# 4  Great value for the money! This location has e...

# %% [markdown]
# **IMPORTANT NOTES TO TAKE:**

# %% [markdown]
# 1. As I can see listings dataset gives the listings for that city, as anyone can guess :) However it is not very much when we look at the count of the listings. I think it is because, these are the ones that are given for 2019-2020 data. And their availability are given for 2020-2021. (Maybe only subset of the listings are shared from AirBnb, who knows)
# 2. The second important dataset is the calendar dataset is that which dates are available for guests. We can try to analyze for which dates you can find accommodation mostly, and which time frames are most suitable for accommodation when considering prices.
# 3. The last dataset which is the reviews dataset is very intriguing because with some basic NLP tools, we can see the sentiments for listings and try to select the best accomodation for that neighbourhood
# 4. As you can see, Seattle has almost two times of Boston listings, maybe Seattle has much more opportunity for accommodations to choose from!!

# %% [markdown]
# **QUESTIONS TO SOLVE**

# %% [markdown]
# After looking at the dataset very roughly, 3 questions popped into my head instantly.

# %% [markdown]
# 1. **What are the most important amenities for a house, and which neighbourhood supplies which amenities for accommodation? And then compare them between `Boston` and `Seattle`.**

# %% [markdown]
# 2. **How does the price change with each month and what is the number of listings for each month?**

# %% [markdown]
# 3. **Can we predict price with some of the basic features? (Not more that 10 distinct features, maybe??)**

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# After coming up with the questions in mind let's try to dig deep into the data.

# %% [markdown]
# Before starting to analyze a random listing, I want to see the neighbourhood distribution in both Boston and Seattle.

# %%
plt.rcParams['figure.figsize'] = [16, 8]

neighbour_groups_seattle = seattle_listings['neighbourhood_cleansed'].value_counts()

(neighbour_groups_seattle/seattle_listings.shape[0]).plot(kind='bar');
plt.title('# of Rented Houses by Seattle Neighbourhood');

# %%
plt.rcParams['figure.figsize'] = [16, 8]

neighbour_groups_boston = boston_listings['neighbourhood_cleansed'].value_counts()

(neighbour_groups_boston/boston_listings.shape[0]).plot(kind='bar');
plt.title('# of Rented Houses by Boston Neighbourhood');

# %% [markdown]
# **IMPORTANT NOTES TO TAKE:**

# %% [markdown]
# 1. As we can see, there are many neighbourhoods around Seattle for a listing; however in Boston this is much more less. As I have said before, there are not many available listings in Boston.
# 2. The other important part is in Boston first 10 neighbourhoods take up the percentage of 80% in number of listings. However, in Seattle it is not very distinctive between neighbourhoods.

# %%
plt.rcParams['figure.figsize'] = [14, 15]

seattle_listings['price_int'] = seattle_listings['price'].map(lambda x: int(x[1:-3].replace(",", "")))

sns.boxplot(x='price_int', y='neighbourhood_group_cleansed', data=seattle_listings, palette='spring');

# %%
plt.rcParams['figure.figsize'] = [14, 17]

boston_listings['price_int'] = boston_listings['price'].map(lambda x: int(x[1:-3].replace(",", "")))

sns.boxplot(x='price_int', y='neighbourhood_cleansed', data=boston_listings, palette='spring');

# %% [markdown]
# **IMPORTANT NOTES TO TAKE:**

# %% [markdown]
# 1. As we can see, there are some outlier houses that are very expensive when compared to the normals. I will graph the distributions one more time but with a threshold for up to $1,000 for a listing price.

# %%
plt.rcParams['figure.figsize'] = [14, 15]

seattle_listings['price_int'] = seattle_listings['price'].map(lambda x: int(x[1:-3].replace(",", "")))

sns.boxplot(x='price_int', y='neighbourhood_group_cleansed',
            data=seattle_listings.loc[seattle_listings['price_int'] <= 1000],
            palette='spring');

# %%
plt.rcParams['figure.figsize'] = [14, 17]

boston_listings['price_int'] = boston_listings['price'].map(lambda x: int(x[1:-3].replace(",", "")))

sns.boxplot(x='price_int', y='neighbourhood_cleansed',
            data=boston_listings.loc[boston_listings['price_int'] <= 1000],
            palette='spring');

# %% [markdown]
# **IMPORTANT NOTES TO TAKE:**

# %% [markdown]
# 1. Our outlier trimming was very simple; however, we could have seen the data distribution much more clearer.
# 2. The important part to consider when outlier trimming is that Leather District in Boston dataset has expensive listings; so when we trimmed the data, the distribution for that neighbourhood changed, significantly.
# 3. So, an important note for me: **LOOK AT THE DISTRIBUTION WHEN HANDLING OUTLIERS!!!**

# %% [markdown]
# First to understand a listing, I will work on a specific listing Id. If I can grasp the details, I can start to answer these questions, one by one.
# I will work on one of the listings from `Seattle` data.

# %%
seattle_listings[seattle_listings['id'] == 708774]
# Out:
#          id                          listing_url       scrape_id last_scraped  \
# 139  708774  https://www.airbnb.com/rooms/708774  20200521035945   2020-05-21
#
#                                                name  \
# 139  Clean and Comfortable Eastlake/Lake Union 1 BR
#
#                                                summary  \
# 139  Modern, clean one-bedroom apartment in Seattle...
#
#                                                  space  \
# 139  This recently renovated, 500-square-foot unit ...
#
#                                            description experiences_offered  \
# 139  Modern, clean one-bedroom apartment in Seattle...                none
#
#                                  neighborhood_overview  \
# 139  Located in Seattle's hip Eastlake neighborhood...
#
#                                                  notes  \
# 139  Pull-out sofa Wi-Fi Comcast Cable 40-inch Sony...
#
#                                                transit  \
# 139  Great access to nearby public buses, and easy ...
#
#                                                 access  \
# 139  Guests will have access to the apartment via a...
#
#                                            interaction  \
# 139  We aim to respond to guest messages as promptl...
#
#                                            house_rules  thumbnail_url  \
# 139  We require our guests to provide us with a dir...            NaN
#
#      medium_url                                        picture_url  \
# 139         NaN  https://a0.muscache.com/im/pictures/a0b92879-3...
#
#      xl_picture_url  host_id                                  host_url  \
# 139             NaN   316200  https://www.airbnb.com/users/show/316200
#
#     host_name  host_since                       host_location  \
# 139   William  2010-12-11  Seattle, Washington, United States
#
#                                             host_about host_response_time  \
# 139  Originally from San Francisco native, I have b...     within an hour
#
#     host_response_rate host_acceptance_rate host_is_superhost  \
# 139               100%                 100%                 t
#
#                                     host_thumbnail_url  \
# 139  https://a0.muscache.com/im/users/316200/profil...
#
#                                       host_picture_url host_neighbourhood  \
# 139  https://a0.muscache.com/im/users/316200/profil...           Eastlake
#
#      host_listings_count  host_total_listings_count  \
# 139                    6                          6
#
#                                     host_verifications host_has_profile_pic  \
# 139  ['email', 'phone', 'facebook', 'reviews', 'kba...                    t
#
#     host_identity_verified                      street neighbourhood  \
# 139                      t  Seattle, WA, United States      Eastlake
#
#     neighbourhood_cleansed neighbourhood_group_cleansed     city state  \
# 139               Eastlake                      Cascade  Seattle    WA
#
#     zipcode   market smart_location country_code        country  latitude  \
# 139   98102  Seattle    Seattle, WA           US  United States     47.64
#
#      longitude is_location_exact property_type        room_type  accommodates  \
# 139 -122.32412                 t     Apartment  Entire home/apt             4
#
#      bathrooms  bedrooms  beds  bed_type  \
# 139        1.0       1.0   2.0  Real Bed
#
#                                              amenities  square_feet    price  \
# 139  {TV,"Cable TV",Internet,Wifi,Kitchen,"Paid par...          NaN  $105.00
#
#     weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 139      $610.00     $2,315.00          $500.00      $100.00                2
#
#     extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 139       $10.00              30             365                      30
#
#      maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 139                      30                    1125                    1125
#
#      minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 139                    30.0                  1125.0     7 months ago
#
#     has_availability  availability_30  availability_60  availability_90  \
# 139                t                0                0                0
#
#      availability_365 calendar_last_scraped  number_of_reviews  \
# 139                 0            2020-05-21                129
#
#      number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 139                      4   2012-12-13  2019-12-21                  97.0
#
#      review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 139                    10.0                       10.0                   10.0
#
#      review_scores_communication  review_scores_location  review_scores_value  \
# 139                         10.0                     9.0                 10.0
#
#     requires_license license             jurisdiction_names instant_bookable  \
# 139                t     NaN  {WASHINGTON," Seattle"," WA"}                t
#
#     is_business_travel_ready          cancellation_policy  \
# 139                        f  strict_14_with_grace_period
#
#     require_guest_profile_picture require_guest_phone_verification  \
# 139                             f                                f
#
#      calculated_host_listings_count  \
# 139                               7
#
#      calculated_host_listings_count_entire_homes  \
# 139                                            7
#
#      calculated_host_listings_count_private_rooms  \
# 139                                             0
#
#      calculated_host_listings_count_shared_rooms  reviews_per_month  price_int
# 139                                            0               1.42        105

# %%
seattle_calendar[seattle_calendar['listing_id'] == 708774].head(30)
# Out:
#     listing_id        date available    price adjusted_price  minimum_nights  \
# 1       708774  2020-05-21         f  $105.00        $105.00              30
# 2       708774  2020-05-22         f  $120.00        $120.00              30
# 3       708774  2020-05-23         f  $120.00        $120.00              30
# 4       708774  2020-05-24         f  $105.00        $105.00              30
# 5       708774  2020-05-25         f  $105.00        $105.00              30
# 6       708774  2020-05-26         f  $105.00        $105.00              30
# 7       708774  2020-05-27         f  $105.00        $105.00              30
# 8       708774  2020-05-28         f  $105.00        $105.00              30
# 9       708774  2020-05-29         f  $120.00        $120.00              30
# 10      708774  2020-05-30         f  $120.00        $120.00              30
# 11      708774  2020-05-31         f  $105.00        $105.00              30
# 12      708774  2020-06-01         f  $105.00        $105.00              30
# 13      708774  2020-06-02         f  $105.00        $105.00              30
# 14      708774  2020-06-03         f  $105.00        $105.00              30
# 15      708774  2020-06-04         f  $105.00        $105.00              30
# 16      708774  2020-06-05         f  $120.00        $120.00              30
# 17      708774  2020-06-06         f  $120.00        $120.00              30
# 18      708774  2020-06-07         f  $105.00        $105.00              30
# 19      708774  2020-06-08         f  $105.00        $105.00              30
# 20      708774  2020-06-09         f  $105.00        $105.00              30
# 21      708774  2020-06-10         f  $105.00        $105.00              30
# 22      708774  2020-06-11         f  $105.00        $105.00              30
# 23      708774  2020-06-12         f  $120.00        $120.00              30
# 24      708774  2020-06-13         f  $120.00        $120.00              30
# 25      708774  2020-06-14         f  $105.00        $105.00              30
# 26      708774  2020-06-15         f  $105.00        $105.00              30
# 27      708774  2020-06-16         f  $105.00        $105.00              30
# 28      708774  2020-06-17         f  $105.00        $105.00              30
# 29      708774  2020-06-18         f  $105.00        $105.00              30
# 30      708774  2020-06-19         f  $120.00        $120.00              30
#
#     maximum_nights
# 1             1125
# 2             1125
# 3             1125
# 4             1125
# 5             1125
# 6             1125
# 7             1125
# 8             1125
# 9             1125
# 10            1125
# 11            1125
# 12            1125
# 13            1125
# 14            1125
# 15            1125
# 16            1125
# 17            1125
# 18            1125
# 19            1125
# 20            1125
# 21            1125
# 22            1125
# 23            1125
# 24            1125
# 25            1125
# 26            1125
# 27            1125
# 28            1125
# 29            1125
# 30            1125

# %%
seattle_reviews[seattle_reviews['listing_id'] == 708774]
# Out:
#        listing_id         id        date  reviewer_id   reviewer_name  \
# 20018      708774    3082551  2012-12-13      2846307         Richard
# 20019      708774    3186563  2012-12-30      1486821           Dolly
# 20020      708774    4010334  2013-04-02      5478592           Nancy
# 20021      708774    4885950  2013-05-31      5200030  Julianna & Bob
# 20022      708774    6430083  2013-08-12      7186917           Cindy
# ...           ...        ...         ...          ...             ...
# 20142      708774  424432517  2019-03-16      8749783        Danielle
# 20143      708774  481960486  2019-07-05       654378             Tom
# 20144      708774  506576937  2019-08-10    121789195          Miriam
# 20145      708774  541125015  2019-10-04    265342453       Sebastian
# 20146      708774  579868986  2019-12-21    104968603         Celeste
#
#                                                 comments
# 20018  As advertised, a clean very central apartment ...
# 20019  Apartment was very clean - exactly as pictured...
# 20020  Apartment was just as advertised and worked we...
# 20021  We had an excellent stay on William's property...
# 20022  Very well appointed and in a great location fo...
# ...                                                  ...
# 20142  This is my 4th time staying here and I always ...
# 20143  We enjoyed our stay at Williams appartment. It...
# 20144  There is no parking. Be ready to walk uphill i...
# 20145  Great place in a great neighborhood. Cozy and ...
# 20146  This is a great, quiet space and William has b...
#
# [129 rows x 6 columns]

# %% [markdown]
# **IMPORTANT NOTES TO TAKE:**

# %% [markdown]
# 1. I think I found a peculiar case for me! Even though in the listings dataset, the listing's price is set as \\$105; when we look at the calendar dataset's price listings, this owner lists his/her property at \\$120 for Friday's and Saturday's.
# 2. I wonder if every householder does this kind of price incrementation!
# 3. Also, for data clarity I will not use the price column in listings dataset; but will use mean or median of the listings' price from calendar dataset.
# 4. If a listing is not available for a specific date, the listing is not shown for that date in the calendar's dataset.
# 5. Review dataset is self-explanatory, I think.

# %% [markdown]
# Let's look another listing from `Boston` dataset!!

# %%
boston_listings[boston_listings['id'] == 3781]
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20200610033559   2020-06-10
#
#                         name  \
# 0  HARBORSIDE-Walk to subway
#
#                                              summary  \
# 0  Fully separate apartment in a two apartment bu...
#
#                                                space  \
# 0  This is a totally separate apartment located o...
#
#                                          description experiences_offered  \
# 0  Fully separate apartment in a two apartment bu...                none
#
#                                neighborhood_overview  \
# 0  Mostly quiet ( no loud music, no crowed sidewa...
#
#                                                notes  \
# 0  Building is on quiet side of airport. Building...
#
#                                              transit  \
# 0  Local subway stop ( Maverick Station on the Bl...
#
#                                               access  \
# 0  Guests solely occupy the 1 floor apartment wit...
#
#                                          interaction           house_rules  \
# 0  We sometimes travel. Always available via: mob...  No pets, no smoking.
#
#    thumbnail_url  medium_url  \
# 0            NaN         NaN
#
#                                          picture_url  xl_picture_url  host_id  \
# 0  https://a0.muscache.com/im/pictures/24670/b2de...             NaN     4804
#
#                                  host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/4804     Frank  2008-12-03
#
#    host_location                                         host_about  \
# 0  Massachusetts  My wife and I and grown children frequently oc...
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0       within a day                75%                  44%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 t  https://a0.muscache.com/im/users/4804/profile_...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/4804/profile_...        East Boston
#
#    host_listings_count  host_total_listings_count  \
# 0                  5.0                        5.0
#
#               host_verifications host_has_profile_pic host_identity_verified  \
# 0  ['email', 'phone', 'reviews']                    t                      f
#
#                       street neighbourhood neighbourhood_cleansed  \
# 0  Boston, MA, United States   East Boston            East Boston
#
#    neighbourhood_group_cleansed    city state zipcode  market smart_location  \
# 0                           NaN  Boston    MA   02128  Boston     Boston, MA
#
#   country_code        country  latitude  longitude is_location_exact  \
# 0           US  United States  42.36413  -71.02991                 t
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0     Apartment  Entire home/apt             2        1.0       1.0   0.0
#
#    bed_type                                          amenities  square_feet  \
# 0  Real Bed  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN
#
#      price weekly_price monthly_price security_deposit cleaning_fee  \
# 0  $125.00      $750.00     $2,250.00            $0.00       $75.00
#
#    guests_included extra_people  minimum_nights  maximum_nights  \
# 0                2        $0.00              28            1125
#
#    minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 0                      28                      28                    1125
#
#    maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0                    1125                    28.0                  1125.0
#
#   calendar_updated has_availability  availability_30  availability_60  \
# 0     4 months ago                t                0                0
#
#    availability_90  availability_365 calendar_last_scraped  number_of_reviews  \
# 0                7                97            2020-06-10                 16
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      1   2015-07-10  2019-12-21                  99.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
#
#   requires_license license                              jurisdiction_names  \
# 0                t     NaN  {"Massachusetts State"," Massachusetts State"}
#
#   instant_bookable is_business_travel_ready cancellation_policy  \
# 0                f                        f     super_strict_30
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  price_int
# 0                                            0               0.27        125

# %%
boston_calendar[boston_calendar['listing_id'] == 3781].head(30)
# Out:
#     listing_id        date available    price adjusted_price  minimum_nights  \
# 0         3781  2020-06-10         f  $125.00        $125.00              28
# 1         3781  2020-06-11         f  $125.00        $125.00              28
# 2         3781  2020-06-12         f  $125.00        $125.00              28
# 3         3781  2020-06-13         f  $125.00        $125.00              28
# 4         3781  2020-06-14         f  $125.00        $125.00              28
# 5         3781  2020-06-15         f  $125.00        $125.00              28
# 6         3781  2020-06-16         f  $125.00        $125.00              28
# 7         3781  2020-06-17         f  $125.00        $125.00              28
# 8         3781  2020-06-18         f  $125.00        $125.00              28
# 9         3781  2020-06-19         f  $125.00        $125.00              28
# 10        3781  2020-06-20         f  $125.00        $125.00              28
# 11        3781  2020-06-21         f  $125.00        $125.00              28
# 12        3781  2020-06-22         f  $125.00        $125.00              28
# 13        3781  2020-06-23         f  $125.00        $125.00              28
# 14        3781  2020-06-24         f  $125.00        $125.00              28
# 15        3781  2020-06-25         f  $125.00        $125.00              28
# 16        3781  2020-06-26         f  $125.00        $125.00              28
# 17        3781  2020-06-27         f  $125.00        $125.00              28
# 18        3781  2020-06-28         f  $125.00        $125.00              28
# 19        3781  2020-06-29         f  $125.00        $125.00              28
# 20        3781  2020-06-30         f  $125.00        $125.00              28
# 21        3781  2020-07-01         f  $125.00        $125.00              28
# 22        3781  2020-07-02         f  $125.00        $125.00              28
# 23        3781  2020-07-03         f  $125.00        $125.00              28
# 24        3781  2020-07-04         f  $125.00        $125.00              28
# 25        3781  2020-07-05         f  $125.00        $125.00              28
# 26        3781  2020-07-06         f  $125.00        $125.00              28
# 27        3781  2020-07-07         f  $125.00        $125.00              28
# 28        3781  2020-07-08         f  $125.00        $125.00              28
# 29        3781  2020-07-09         f  $125.00        $125.00              28
#
#     maximum_nights
# 0             1125
# 1             1125
# 2             1125
# 3             1125
# 4             1125
# 5             1125
# 6             1125
# 7             1125
# 8             1125
# 9             1125
# 10            1125
# 11            1125
# 12            1125
# 13            1125
# 14            1125
# 15            1125
# 16            1125
# 17            1125
# 18            1125
# 19            1125
# 20            1125
# 21            1125
# 22            1125
# 23            1125
# 24            1125
# 25            1125
# 26            1125
# 27            1125
# 28            1125
# 29            1125

# %%
boston_reviews[boston_reviews['listing_id'] == 3781]
# Out:
#     listing_id         id        date  reviewer_id reviewer_name  \
# 0         3781   37776825  2015-07-10     36059247          Greg
# 1         3781   41842494  2015-08-09     10459388           Tai
# 2         3781   45282151  2015-09-01     12264652        Damien
# 3         3781   49022647  2015-09-30     41426327          Mike
# 4         3781   52503327  2015-10-30     15151513          Ivan
# 5         3781   63371931  2016-02-22     55456499     John-Mark
# 6         3781   67909504  2016-04-01     55456499     John-Mark
# 7         3781   97906006  2016-08-28     88528884         Elisa
# 8         3781  105143774  2016-09-30      1342806        Nicole
# 9         3781  129692749  2017-02-01     55126634        Carlos
# 10        3781  155725362  2017-05-28    117390053       Carolyn
# 11        3781  184356065  2017-08-19     70187382        Justin
# 12        3781  194026175  2017-09-15     11888800          John
# 13        3781  284969158  2018-07-02    173840231         Artur
# 14        3781  415389126  2019-02-22     83031353        Norman
# 15        3781  579765013  2019-12-21      3918963       Antoine
#
#                                              comments
# 0   The apartment was as advertised and Frank was ...
# 1   It was a pleasure to stay at Frank's place. Th...
# 2   The apartment description is entirely faithful...
# 3   Thoroughly enjoyed my time at Frank's home. Ha...
# 4   Great value for the money! This location has e...
# 5   Frank was very accommodating throughout my sta...
# 6   Excellent! This was my second stay at the Jeff...
# 7   Frank was a wonderful and accommodating host. ...
# 8   Frank was great, the apartment has everything ...
# 9   Very nice. Comfortable apartment. Good locatio...
# 10  Apartment was everything described. Very clean...
# 11  Frank's place is in a great part of East Bosto...
# 12  Franks' place is the ground floor unit in a 3 ...
# 13       Great place, amazing city, fantastic host!!!
# 14  My partner and I stayed at Frank's apartment f...
# 15  I liked very much this apartment rented by Fra...

# %% [markdown]
# This householder is much more consistent as you can see. He/she doesn't charge more for people who want to relax a bit on weekends after working very hard :):)
